# %%
# Distributed under the MIT License.
# See LICENSE.txt for details.
import h5py

# %%
with h5py.File("/home/cillian/.sf_spectre/runs/CircularOrbit/test_it_2/ScalarSelfForceVolume0.h5", "r") as VolumeData:
    print(VolumeData["VolumeData.vol/ObservationId4817489997503763368"].keys())
    ReFixedSource = VolumeData["VolumeData.vol/ObservationId4817489997503763368/Re(FixedSource(MMode))"][:]
    ReMMode = VolumeData["VolumeData.vol/ObservationId4817489997503763368/Re(MMode)"][:]
    ImMMode = VolumeData["VolumeData.vol/ObservationId4817489997503763368/Im(MMode)"][:]
# Out:
# <KeysViewHDF5 ['BoyerLindquistRadius', 'Im(Alpha)', 'Im(Beta)', 'Im(BoostFunction)', 'Im(BoostFunctionDeriv)', 'Im(FixedSource(MMode))', 'Im(Gamma_x)', 'Im(Gamma_y)', 'Im(MMode)', 'Im(SingularField)', 'InertialCoordinates_x', 'InertialCoordinates_y', 'Re(Alpha)', 'Re(Beta)', 'Re(BoostFunction)', 'Re(BoostFunctionDeriv)', 'Re(FixedSource(MMode))', 'Re(Gamma_x)', 'Re(Gamma_y)', 'Re(MMode)', 'Re(SingularField)', 'bases', 'connectivity', 'domain', 'functions_of_time', 'grid_names', 'quadratures', 'total_extents']>

# %%
print(ReFixedSource)
# Out:
# [-0.00062144  0.00220054 -0.00457453 ...  0.          0.
#   0.        ]

# %%
for i in ReMMode:
    if i != 0:
        print(i)
for i in ImMMode:
    if i != 0:
        print(i)

# %%
with h5py.File("/home/cillian/.sf_spectre/runs/CircularOrbit/test_it_2/ScalarSelfForceReductions.h5", "r") as ReductionData:
    print(ReductionData.keys())
    SelfForce = ReductionData["SelfForce.dat"][:]
# Out:
# <KeysViewHDF5 ['GmresResiduals.dat', 'MultigridResiduals.dat', 'Norms.dat', 'SchwarzSmootherResiduals.dat', 'SchwarzSmootherSubdomainSolves.dat', 'SelfForce.dat', 'src.tar.gz']>

# %%
print(SelfForce)
# Out:
# [[ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#    0.00000000e+00  0.00000000e+00  0.00000000e+00]
#  [ 1.00000000e+00 -2.62107517e-03  3.83791351e-03 -8.15149896e-04
#    6.49662799e-04  0.00000000e+00  0.00000000e+00 -1.51195751e-04
#    9.08526120e-05  0.00000000e+00  0.00000000e+00]
#  [ 1.00000000e+00 -2.62107517e-03  3.83791351e-03 -8.15149896e-04
#    6.49662799e-04  0.00000000e+00  0.00000000e+00 -1.51195751e-04
#    9.08526120e-05  0.00000000e+00  0.00000000e+00]
#  [ 2.00000000e+00 -2.69907536e-03  3.83576575e-03 -7.62442234e-04
#    6.55388237e-04  0.00000000e+00  0.00000000e+00 -1.36410580e-04
#    9.14061764e-05  0.00000000e+00  0.00000000e+00]
#  [ 2.00000000e+00 -2.69907536e-03  3.83576575e-03 -7.62442234e-04
#    6.55388237e-04  0.00000000e+00  0.00000000e+00 -1.36410580e-04
#    9.14061764e-05  0.00000000e+00  0.00000000e+00]]
